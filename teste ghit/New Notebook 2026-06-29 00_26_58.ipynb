# %%
#teste

# %%
# teste de commit

# %% [markdown]
# Teste de alteracao no DataBricks

# %%
print("Hello World")

# %%
print("Emerson")

# %% [markdown]
# Teste de atalizacao

# %% [markdown]
# testando novamente
